# %% [markdown]
# Import SysMLv2 Model:

# %%
import syside

EXAMPLE_DIR = "/Users/alejandronietocuatenta/Documents/SysML_v2/project_Electronics_Basics/"
MODEL_FILE_PATH = EXAMPLE_DIR + "electronics_basic.sysml"
(model, diagnostics) = syside.load_model([MODEL_FILE_PATH])

# %% [markdown]
# Check Model Class names:

# %%
for doc in model.user_docs:
    print(doc)
    with doc.lock() as locked:
        print(f"Model sexp: {syside.sexp(locked.root_node)}")
# Out:
# <syside.core.SharedMutex object at 0x1047847c0>
# Model sexp: (Namespace
#   (OwningMembership
#     (Package electronics_basic
#       (NamespaceImport)
#       (NamespaceImport)
#       (OwningMembership
#         (PartDefinition Battery
#           (Subclassification)
#           (FeatureMembership
#             (PortUsage +
#               (Subsetting)))
#           (FeatureMembership
#             (PortUsage -
#               (Subsetting)))))
#       (OwningMembership
#         (PartDefinition Resistor
#           (Subclassification)
#           (FeatureMembership
#             (PortUsage a
#               (Subsetting)))
#           (FeatureMembership
#             (PortUsage b
#               (Subsetting)))))
#       (OwningMembership
#         (PartDefinition LED
#           (Subclassification)
#           (FeatureMembership
#             (PortUsage a
#               (Subsetting)))
#           (FeatureMembership
#             (PortUsage k
#               (Subsetting)))
#           (FeatureMembership
#             (AttributeUsage forwardVoltage
#               (FeatureTyping)
#               (Subsetting)
#               (FeatureValue
#                 (LiteralRational
#                   (Subsetting)
#                   (TypeFeaturing)))))
#           (FeatureMembership
#             (AttributeUsage forwardCurrent
#               (FeatureTyping)
#               (Subsetting)
#               (FeatureValue
#                 (LiteralRational
#                   (Subsetting)
#                   (TypeFeaturing)))))
#           (FeatureMembership
#             (AttributeUsage effectiveResistance
#               (FeatureTyping)
#               (Subsetting)
#               (FeatureValue
#                 (OperatorExpression
#                   (Subsetting)
#                   (TypeFeaturing)
#                   (ParameterMembership
#                     (Feature
#                       (Subsetting)
#                       (FeatureValue
#                         (FeatureReferenceExpression
#                           (Subsetting)
#                           (TypeFeaturing)
#                           (Membership)))))
#                   (ParameterMembership
#                     (Feature
#                       (Subsetting)
#                       (FeatureValue
#                         (FeatureReferenceExpression
#                           (Subsetting)
#                           (TypeFeaturing)
#                           (Membership)))))))))))
#       (OwningMembership
#         (PartUsage circuit
#           (Subsetting)
#           (FeatureMembership
#             (PortUsage supply
#               (Subsetting)))
#           (FeatureMembership
#             (PortUsage communication
#               (Subsetting)))
#           (FeatureMembership
#             (PartUsage r1
#               (FeatureTyping)
#               (Subsetting)
#               (FeatureMembership
#                 (AttributeUsage resistance
#                   (FeatureTyping)
#                   (Subsetting)
#                   (FeatureValue
#                     (LiteralRational
#                       (Subsetting)
#                       (TypeFeaturing)))))))
#           (FeatureMembership
#             (PartUsage r2
#               (FeatureTyping)
#               (Subsetting)
#               (FeatureMembership
#                 (AttributeUsage resistance
#                   (FeatureTyping)
#                   (Subsetting)
#                   (FeatureValue
#                     (LiteralRational
#                       (Subsetting)
#                       (TypeFeaturing)))))))
#           (FeatureMembership
#             (PartUsage led1
#               (FeatureTyping)
#               (Subsetting)))))
#       (OwningMembership
#         (PartUsage b1
#           (FeatureTyping)
#           (Subsetting)
#           (FeatureMembership
#             (AttributeUsage voltage
#               (FeatureTyping)
#               (Subsetting)
#               (FeatureValue
#                 (LiteralRational
#                   (Subsetting)
#                   (TypeFeaturing))))))))))

# %% [markdown]
# Check PartDefinition in Model:

# %%
for partDefinition in model.nodes(syside.PartDefinition):
    print(partDefinition)
    # print(f"\tis_individual: {partDefinition.is_individual}") # bool (not so relevant)
    print(f"\towned_ports: {len(list(partDefinition.owned_ports))}")
    print(f"\towned_attributes: {len(list(partDefinition.owned_attributes))}") # class LazyIterator
# Out:
# electronics_basic::Battery
# 	owned_ports: 2
# 	owned_attributes: 0
# electronics_basic::Resistor
# 	owned_ports: 2
# 	owned_attributes: 0
# electronics_basic::LED
# 	owned_ports: 2
# 	owned_attributes: 3

# %% [markdown]
# Check PartUsage in Model:

# %%
for partUsage in model.nodes(syside.PartUsage):
    print(partUsage)
    # print(f"\tpart_definitions: {len(list(partUsage.part_definitions))}") # 0: Part, 1: Definition
    print(f"\tnested_parts: {len(list(partUsage.nested_parts))}")
    print(f"\tnested_ports: {len(list(partUsage.nested_ports))}")
# Out:
# electronics_basic::circuit
# 	nested_parts: 3
# 	nested_ports: 2
# electronics_basic::b1
# 	nested_parts: 0
# 	nested_ports: 0
# electronics_basic::circuit::r1
# 	nested_parts: 0
# 	nested_ports: 0
# electronics_basic::circuit::r2
# 	nested_parts: 0
# 	nested_ports: 0
# electronics_basic::circuit::led1
# 	nested_parts: 0
# 	nested_ports: 0

# %% [markdown]
# Evaluate Model attributes:

# %%
def safe(expr_func):
    try:
        return expr_func()
    except AttributeError:
        return None

# %%
for attributeUsage in model.nodes(syside.AttributeUsage):
    print(attributeUsage)
    # print(f"\tname: {attributeUsage.name}") # redunda info, already included in print(attributeUsage)
    print(f"\tfeature_value_expression: {safe(lambda: attributeUsage.feature_value_expression.value)}") # need function "safe" defined in the above cell
    print(f"\tevaluate expression: {syside.Compiler().evaluate(attributeUsage.feature_value_expression)[0]}")
# Out:
# electronics_basic::LED::forwardVoltage
# 	feature_value_expression: 2.0
# 	evaluate expression: 2.0
# electronics_basic::LED::forwardCurrent
# 	feature_value_expression: 0.02
# 	evaluate expression: 0.02
# electronics_basic::LED::effectiveResistance
# 	feature_value_expression: None
# 	evaluate expression: 100.0
# electronics_basic::circuit::r1::resistance
# 	feature_value_expression: 100.0
# 	evaluate expression: 100.0
# electronics_basic::circuit::r2::resistance
# 	feature_value_expression: 400.0
# 	evaluate expression: 400.0
# electronics_basic::b1::voltage
# 	feature_value_expression: 5.0
# 	evaluate expression: 5.0

# %% [markdown]
# Check Constrain Arguments:

# %%
for operatorExpression in model.nodes(syside.OperatorExpression):
    print(operatorExpression)
